# %% [markdown]
# # 🚀 Memory Management - Part 1 - Sessions
#
# **Welcome to Day 3 of the Kaggle 5-day Agents course!**
#
# In this notebook, you'll learn:
#
# - ✅ What sessions are and how to use them in your agent
# - ✅ How to build *stateful* agents with sessions and events
# - ✅ How to persist sessions in a database
# - ✅ Context management practices such as context compaction
# - ✅ Best practices for sharing session State

# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %% [markdown]
# ### 1.3: Import ADK components
#
# Now, import the specific components you'll need from the Agent Development Kit and the Generative AI library. This keeps your code organized and ensures we have access to the necessary building blocks.

# %%
from typing import Any, Dict

from google.adk.agents import Agent, LlmAgent
from google.adk.apps.app import App, EventsCompactionConfig
from google.adk.models.google_llm import Gemini
from google.adk.sessions import DatabaseSessionService
from google.adk.sessions import InMemorySessionService
from google.adk.runners import Runner
from google.adk.tools.tool_context import ToolContext
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %% [markdown]
# ### 1.4: Helper functions
#
# Helper function that manages a complete conversation session, handling session
# creation/retrieval, query processing, and response streaming. It supports
# both single queries and multiple queries in sequence.
#
# Example:
#
# ```
# >>> await run_session(runner, "What is the capital of France?", "geography-session")
# >>> await run_session(runner, ["Hello!", "What's my name?"], "user-intro-session")
# ```

# %%
# Define helper functions that will be reused throughout the notebook
async def run_session(
    runner_instance: Runner,
    user_queries: list[str] | str = None,
    session_name: str = "default",
):
    print(f"\n ### Session: {session_name}")

    # Get app name from the Runner
    app_name = runner_instance.app_name

    # Attempt to create a new session or retrieve an existing one
    try:
        session = await session_service.create_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )
    except:
        session = await session_service.get_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )

    # Process queries if provided
    if user_queries:
        # Convert single query to list for uniform processing
        if type(user_queries) == str:
            user_queries = [user_queries]

        # Process each query in the list sequentially
        for query in user_queries:
            print(f"\nUser > {query}")

            # Convert the query string to the ADK Content format
            query = types.Content(role="user", parts=[types.Part(text=query)])

            # Stream the agent's response asynchronously
            async for event in runner_instance.run_async(
                user_id=USER_ID, session_id=session.id, new_message=query
            ):
                # Check if the event contains valid content
                if event.content and event.content.parts:
                    # Filter out empty or "None" responses before printing
                    if (
                        event.content.parts[0].text != "None"
                        and event.content.parts[0].text
                    ):
                        print(f"{MODEL_NAME} > ", event.content.parts[0].text)
    else:
        print("No queries!")


print("✅ Helper functions defined.")
# Out:
# ✅ Helper functions defined.

# %% [markdown]
# ### 1.5: Configure Retry Options
#
# When working with LLMs, you may encounter transient errors like rate limits or temporary service unavailability. Retry options automatically handle these failures by retrying the request with exponential backoff.

# %%
retry_config = types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],  # Retry on these HTTP errors
)

# %% [markdown]
# ---
# ## 🤹 Section 2: Session Management
#
# ### 2.1 The Problem
#
# At their core, Large Language Models are **inherently stateless**. Their awareness is confined to the information you provide in a single API call. This means an agent without proper context management will react to the current prompt without considering any previous history.
#
# **❓ Why does this matter?** Imagine trying to have a meaningful conversation with someone who forgets everything you've said after each sentence. That's the challenge we face with raw LLMs!
#
# In ADK, we use `Sessions` for **short term memory management** and `Memory` for **long term memory.** In the next notebook, you'll focus on `Memory`.

# %% [markdown]
# ### 2.2 What is a Session?
#
# #### **📦 Session**
#
# A session is a container for conversations. It encapsulates the conversation history in a chronological manner and also records all tool interactions and responses for a **single, continuous conversation**. A session is tied to a user and agent; it is not shared with other users. Similarly, a session history for an Agent is not shared with other Agents.
#
# In ADK, a **Session** is comprised of two key components `Events` and `State`:
#
# **📝 Session.Events**:
#
# > While a session is a container for conversations, `Events` are the building blocks of a conversation.
# >
# > Example of Events:
# > - *User Input*: A message from the user (text, audio, image, etc.)
# > - *Agent Response*: The agent's reply to the user
# > - *Tool Call*: The agent's decision to use an external tool or API
# > - *Tool Output*: The data returned from a tool call, which the agent uses to continue its reasoning
#
#
# **{} Session.State**:
#
# > `session.state` is the Agent's scratchpad, where it stores and updates dynamic details needed during the conversation. Think of it as a global `{key, value}` pair storage which is available to all subagents and tools.

# %% [markdown]
# <img src="https://storage.googleapis.com/github-repo/kaggle-5days-ai/day3/session-state-and-events.png" width="320" alt="Session state and events">
#
# <!-- ```mermaid
# graph TD
#     subgraph A["Agentic Application"];
#         subgraph U["User"]
#             subgraph S1["Session"]
#                 D1["Session.Events"]
#                 D2["Session.State"]
#             end
#         end
#     end
# ``` -->

# %% [markdown]
# ### 2.3 How to manage sessions?
#
# An agentic application can have multiple users and each user may have multiple sessions with the application.
# To manage these sessions and events, ADK offers a **Session Manager** and **Runner**.
#
# 1. **`SessionService`**: The storage layer
#    - Manages creation, storage, and retrieval of session data
#    - Different implementations for different needs (memory, database, cloud)
#
# 2. **`Runner`**: The orchestration layer
#    - Manages the flow of information between user and agent
#    - Automatically maintains conversation history
#    - Handles the Context Engineering behind the scenes
#
# Think of it like this:
#
# - **Session** = A notebook 📓
# - **Events** = Individual entries in a single page 📝
# - **SessionService** = The filing cabinet storing notebooks 🗄️
# - **Runner** = The assistant managing the conversation 🤖

# %% [markdown]
# ### 2.4 Implementing Our First Stateful Agent
#
# Let's build our first stateful agent, that can remember and have constructive conversations.
#
# ADK offers different types of sessions suitable for different needs. As a start, we'll start with a simple Session Management option (`InMemorySessionService`):

# %%
APP_NAME = "default"  # Application
USER_ID = "default"  # User
SESSION = "default"  # Session

MODEL_NAME = "gemini-2.5-flash-lite"


# Step 1: Create the LLM Agent
root_agent = Agent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="text_chat_bot",
    description="A text chatbot",  # Description of the agent's purpose
)

# Step 2: Set up Session Management
# InMemorySessionService stores conversations in RAM (temporary)
session_service = InMemorySessionService()

# Step 3: Create the Runner
runner = Runner(agent=root_agent, app_name=APP_NAME, session_service=session_service)

print("✅ Stateful agent initialized!")
print(f"   - Application: {APP_NAME}")
print(f"   - User: {USER_ID}")
print(f"   - Using: {session_service.__class__.__name__}")
# Out:
# ✅ Stateful agent initialized!
#    - Application: default
#    - User: default
#    - Using: InMemorySessionService

# %% [markdown]
# ### 2.5 Testing Our Stateful Agent
#
# Now let's see the magic of sessions in action!

# %%
# Run a conversation with two queries in the same session
# Notice: Both queries are part of the SAME session, so context is maintained
await run_session(
    runner,
    [
        "Hi, I am Sam! What is the capital of United States?",
        "Hello! What is my name?",  # This time, the agent should remember!
    ],
    "stateful-agentic-session",
)
# Out:
#  ### Session: stateful-agentic-session
#
# User > Hi, I am Sam! What is the capital of United States?
# gemini-2.5-flash-lite >  Hi Sam! The capital of the United States is Washington, D.C.
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  Your name is Sam.

# %% [markdown]
# 🎉 **Success!** The agent remembered your name because both queries were part of the same session. The Runner automatically maintained the conversation history.
#
# But there's a catch: `InMemorySessionService` is temporary. **Once the application stops, all conversation history is lost.**

# %% [markdown]
# ### 🛑 (Optional) 2.6 Testing Agent's forgetfulness
#
# > To verify that the agent forgets the conversation, **restart the kernel**. Then, **run ALL the previous cells in this notebook EXCEPT the `run_session` in 2.5.**
# >
# > Now run the cell below. You'll see that the agent doesn't remember anything from the previous conversation.

# %%
# Run this cell after restarting the kernel. All this history will be gone...
await run_session(
    runner,
    ["What did I ask you about earlier?", "And remind me, what's my name?"],
    "stateful-agentic-session",
)  # Note, we are using same session name
# Out:
#  ### Session: stateful-agentic-session
#
# User > What did I ask you about earlier?
# gemini-2.5-flash-lite >  You asked me about the capital of the United States.
#
# User > And remind me, what's my name?
# gemini-2.5-flash-lite >  Your name is Sam.

# %% [markdown]
# ### The Problem
#
# Session information is not persistent (i.e., meaningful conversations are lost). While this is advantageous in testing environments, **in the real world, a user should be able to refer from past and resume conversations.** To achieve this, we must persist information.

# %% [markdown]
# ---
# ## 📈 Section 3: Persistent Sessions with `DatabaseSessionService`
#
# While `InMemorySessionService` is great for prototyping, real-world applications need conversations to survive restarts, crashes, and deployments. Let's level up to persistent storage!
#
# ### 3.1 Choosing the Right SessionService
#
# ADK provides different SessionService implementations for different needs:
#
# | Service | Use Case | Persistence | Best For |
# |---------|----------|-------------|----------|
# | **InMemorySessionService** | Development & Testing | ❌ Lost on restart | Quick prototypes |
# | **DatabaseSessionService** | Self-managed apps | ✅ Survives restarts | Small to medium apps |
# | **Agent Engine Sessions** | Production on GCP | ✅ Fully managed | Enterprise scale |

# %% [markdown]
# ### 3.2 Implementing Persistent Sessions
#
# Let's upgrade to `DatabaseSessionService` using SQLite. This gives us persistence without needing a separate database server for this demo.
#
# Let's create a `chatbot_agent` capable of having a conversation with the user.

# %%
# Step 1: Create the same agent (notice we use LlmAgent this time)
chatbot_agent = LlmAgent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="text_chat_bot",
    description="A text chatbot with persistent memory",
)

# Step 2: Switch to DatabaseSessionService
# SQLite database will be created automatically
db_url = "sqlite:///my_agent_data.db"  # Local SQLite file
session_service = DatabaseSessionService(db_url=db_url)

# Step 3: Create a new runner with persistent storage
runner = Runner(agent=chatbot_agent, app_name=APP_NAME, session_service=session_service)

print("✅ Upgraded to persistent sessions!")
print(f"   - Database: my_agent_data.db")
print(f"   - Sessions will survive restarts!")
# Out:
# ✅ Upgraded to persistent sessions!
#    - Database: my_agent_data.db
#    - Sessions will survive restarts!

# %% [markdown]
# ### 3.3 Test Run 1: Verifying Persistence
#
# In this first test run, we'll start a new conversation with the session ID `test-db-session-01`. We will first introduce our name as 'Sam' and then ask a question. In the second turn, we will ask the agent for our name.
#
# Since we are using `DatabaseSessionService`, the agent should remember the name.
#
# After the conversation, we'll inspect the `my_agent_data.db` SQLite database directly to see how the conversation `events` (the user queries and model responses) are stored.

# %%
await run_session(
    runner,
    ["Hi, I am Sam! What is the capital of the United States?", "Hello! What is my name?"],
    "test-db-session-01",
)
# Out:
#  ### Session: test-db-session-01
#
# User > Hi, I am Sam! What is the capital of the United States?
# gemini-2.5-flash-lite >  Hi Sam! The capital of the United States is Washington, D.C.
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  Your name is Sam.

# %% [markdown]
# ### 🛑 (Optional) 3.4 Test Run 2: Resuming a Conversation
#
# > ‼️ Now, let's repeat the test again, but this time, **let's stop this Kaggle Notebook's kernel and restart it again.**
# >
# > 1. Run all the previous cells in the notebook, **EXCEPT** the previous Section 3.3 (`run_session` cell).
# >
# > 2. Now, run the below cell with the **same session ID** (`test-db-session-01`).
#
# We will ask a new question and then ask for our name again. **Because the session is loaded from the database, the agent should still remember** that our name is 'Sam' from the first test run. This demonstrates the power of persistent sessions.

# %%
await run_session(
    runner,
    ["What is the capital of India?", "Hello! What is my name?"],
    "test-db-session-01",
)
# Out:
#  ### Session: test-db-session-01
#
# User > What is the capital of India?
# gemini-2.5-flash-lite >  The capital of India is New Delhi.
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  Your name is Sam.

# %% [markdown]
# ### 3.5 Let's verify that the session data is isolated
#
# As mentioned earlier, a session is private conversation between an Agent and a User (i.e., two sessions do not share information). Let's run our `run_session` with a different session name `test-db-session-02` to confirm this.

# %%
await run_session(
    runner, ["Hello! What is my name?"], "test-db-session-02"
)  # Note, we are using new session name
# Out:
#  ### Session: test-db-session-02
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  I do not have access to personal information such as your name. I am a text chatbot.

# %% [markdown]
# ### 3.6 How are the events stored in the Database?
#
# Since we are using a sqlite DB to store information, let's have a quick peek to see how information is stored.

# %%
import sqlite3

def check_data_in_db():
    with sqlite3.connect("my_agent_data.db") as connection:
        cursor = connection.cursor()
        result = cursor.execute(
            "select app_name, session_id, author, content from events"
        )
        print([_[0] for _ in result.description])
        for each in result.fetchall():
            print(each)


check_data_in_db()
# Out:
# ['app_name', 'session_id', 'author', 'content']
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hi, I am Sam! What is the capital of the United States?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Hi Sam! The capital of the United States is Washington, D.C."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Your name is Sam."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "What is the capital of India?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "The capital of India is New Delhi."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Your name is Sam."}], "role": "model"}')
# ('default', 'test-db-session-02', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-02', 'text_chat_bot', '{"parts": [{"text": "I do not have access to personal information such as your name. I am a text chatbot."}], "role": "model"}')

# %% [markdown]
# ---
# ## ⏳ Section 4: Context Compaction
#
# As you can see, all the events are stored in full in the session Database, and this quickly adds up. For a long, complex task, this list of events can become very large, leading to slower performance and higher costs.
#
# But what if we could automatically summarize the past? Let's use ADK's **Context Compaction** feature to see **how to automatically reduce the context that's stored in the Session.**

# %% [markdown]
# <img src="https://storage.googleapis.com/github-repo/kaggle-5days-ai/day3/context-compaction.png" width="1400" alt="Context compaction">

# %% [markdown]
# ### 4.1 Create an App for the agent
#
# To enable this feature, let's use the same `chatbot_agent` we created in Section 3.2.
#
# The first step is to create an object called `App`. We'll give it a name and pass in our chatbot_agent.
#
# We'll also create a new config to do the Context Compaction. This **`EventsCompactionConfig`** defines two key variables:
#
# - **compaction_interval**: Asks the Runner to compact the history after every `n` conversations
# - **overlap_size**: Defines the number of previous conversations to retain for overlap
#
# We'll then provide this app to the Runner.

# %%
# Re-define our app with Events Compaction enabled
research_app_compacting = App(
    name="research_app_compacting",
    root_agent=chatbot_agent,
    # This is the new part!
    events_compaction_config=EventsCompactionConfig(
        compaction_interval=3,  # Trigger compaction every 3 invocations
        overlap_size=1,  # Keep 1 previous turn for context
    ),
)

db_url = "sqlite:///my_agent_data.db"  # Local SQLite file
session_service = DatabaseSessionService(db_url=db_url)

# Create a new runner for our upgraded app
research_runner_compacting = Runner(
    app=research_app_compacting, session_service=session_service
)


print("✅ Research App upgraded with Events Compaction!")
# Out:
# ✅ Research App upgraded with Events Compaction!
# /tmp/ipykernel_62/3773147741.py:6: UserWarning: [EXPERIMENTAL] EventsCompactionConfig: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   events_compaction_config=EventsCompactionConfig(

# %% [markdown]
# ### 4.2 Running the Demo
#
# Now, let's have a conversation that is long enough to trigger the compaction. When you run the cell below, the output will look like a normal conversation. However, because we configured our `App`, a compaction process will run silently in the background after the 3rd invocation.
#
# In the next step, we'll prove that it happened.

# %%
# Turn 1
await run_session(
    research_runner_compacting,
    "What is the latest news about AI in healthcare?",
    "compaction_demo",
)

# Turn 2
await run_session(
    research_runner_compacting,
    "Are there any new developments in drug discovery?",
    "compaction_demo",
)

# Turn 3 - Compaction should trigger after this turn!
await run_session(
    research_runner_compacting,
    "Tell me more about the second development you found.",
    "compaction_demo",
)

# Turn 4
await run_session(
    research_runner_compacting,
    "Who are the main companies involved in that?",
    "compaction_demo",
)
# Out:
#  ### Session: compaction_demo
#
# User > What is the latest news about AI in healthcare?
# gemini-2.5-flash-lite >  The field of AI in healthcare is incredibly dynamic, with new developments emerging almost daily. However, I can give you a summary of some of the most significant and recent trends and news:
#
# **Key Areas of Advancement and News:**
#
# *   **Drug Discovery and Development:** This remains a hot area. AI algorithms are being used to:
#     *   **Identify new drug targets:** Predicting which proteins or pathways are most likely to be involved in a disease.
#     *   **Design novel drug molecules:** Generating chemical structures with desired properties.
#     *   **Optimize clinical trials:** Identifying ideal patient populations, predicting trial success rates, and streamlining data analysis.
#     *   **News:** Companies like **Atomwise**, **BenevolentAI**, and **Exscientia** are consistently announcing breakthroughs and partnerships, often with significant funding rounds. There's also a focus on using AI to repurpose existing drugs for new diseases.
#
# *   **Medical Imaging Analysis:** AI continues to revolutionize how radiologists and pathologists interpret images.
#     *   **Detection and diagnosis:** AI models can identify subtle anomalies in X-rays, CT scans, MRIs, and pathology slides that might be missed by the human eye, leading to earlier and more accurate diagnoses for conditions like cancer, diabetic retinopathy, and cardiovascular disease.
#     *   **Workflow optimization:** AI can triage urgent cases, automate measurements, and reduce the workload on specialists.
#     *   **News:** Major players like **Google Health**, **Siemens Healthineers**, and **GE Healthcare** are heavily invested in this space, with FDA approvals for AI-powered diagnostic tools becoming more common.
#
# *   **Personalized Medicine and Genomics:** AI is crucial for making sense of vast amounts of genomic and patient data to tailor treatments.
#     *   **Predicting treatment response:** Identifying which patients are most likely to benefit from specific therapies based on their genetic makeup and other factors.
#     *   **Risk prediction:** Forecasting an individual's susceptibility to certain diseases.
#     *   **News:** Advancements in AI are accelerating the interpretation of complex genomic data, paving the way for more precise and effective cancer treatments and the management of rare genetic disorders.
#
# *   **AI-Powered Diagnostics and Monitoring:** Beyond imaging, AI is being integrated into other diagnostic tools and remote monitoring systems.
#     *   **Digital pathology:** Automating the analysis of tissue samples.
#     *   **AI-powered chatbots and virtual assistants:** Providing initial patient triage, answering health questions, and assisting with appointment scheduling.
#     *   **Wearable devices:** AI analyzes data from wearables to detect early signs of disease or monitor chronic conditions.
#     *   **News:** There's a growing focus on developing AI tools that can be used at the point of care, improving efficiency and accessibility.
#
# *   **Robotics in Surgery and Patient Care:** AI is enhancing the capabilities of surgical robots and assisting in patient care.
#     *   **Surgical assistance:** AI can provide real-time guidance to surgeons, improve precision, and automate certain surgical tasks.
#     *   **Robotic assistance for elderly or disabled patients:** Robots are being developed to help with tasks like lifting, mobility, and daily living.
#     *   **News:** Companies like **Intuitive Surgical** continue to innovate in robotic surgery, and there's growing interest in AI's role in improving rehabilitation and elderly care.
#
# *   **Operational Efficiency and Administration:** AI is also being deployed to streamline administrative tasks and improve hospital operations.
#     *   **Predictive analytics:** Forecasting patient flow, resource needs, and hospital readmissions.
#     *   **Automating billing and coding:** Reducing errors and improving efficiency.
#     *   **News:** Hospitals are increasingly looking to AI to reduce costs, improve patient throughput, and alleviate staff burnout.
#
# **Recent Trends and Emerging Areas:**
#
# *   **Generative AI (like Large Language Models - LLMs):** This is a major current focus.
#     *   **Clinical documentation:** LLMs are being explored to automate the creation of clinical notes, discharge summaries, and referral letters, freeing up clinician time.
#     *   **Patient education:** Creating personalized and understandable health information for patients.
#     *   **Research summarization:** Quickly digesting and summarizing large volumes of research papers.
#     *   **Challenges:** Ensuring accuracy, patient privacy, and ethical use are paramount concerns.
#     *   **News:** Major tech companies are partnering with healthcare providers to develop and deploy LLM-based solutions.
#
# *   **Explainable AI (XAI):** As AI systems become more complex, there's a growing demand for transparency. XAI aims to make AI decisions understandable to humans, which is crucial for trust and regulatory approval in healthcare.
#
# *   **AI for Mental Health:** AI is being used to develop tools for diagnosing, monitoring, and even treating mental health conditions, often through chatbots or analysis of speech and behavioral patterns.
#
# *   **Regulatory Landscape:** Regulatory bodies like the FDA are actively developing frameworks for approving and overseeing AI-powered medical devices and software. This is a critical area to watch as it impacts the adoption of new AI technologies.
#
# **Where to Find More Specific News:**
#
# To get the absolute latest news, I recommend following:
#
# *   **Reputable healthcare technology news outlets:** FierceBiotech, STAT News, MedTech Dive, Healthcare IT News.
# *   **Major tech company blogs and newsrooms:** Google Health, Microsoft Healthcare, IBM Watson Health.
# *   **Medical journals and research publications:** Nature Medicine, The Lancet Digital Health, JAMA Network Open.
# *   **Industry conferences and reports:** HIMSS, RSNA, and reports from consulting firms like Deloitte or McKinsey.
#
# The pace of innovation is rapid, so staying updated requires ongoing engagement with these sources!
#
#  ### Session: compaction_demo
#
# User > Are there any new developments in drug discovery?
# gemini-2.5-flash-lite >  Yes, there are **constant and exciting new developments in drug discovery**, driven heavily by advancements in AI and other cutting-edge technologies. It's a field experiencing a major transformation. Here are some of the key areas where new developments are happening:
#
# **1. AI and Machine Learning as the Central Engine:**
#
# *   **Accelerated Target Identification:** AI models are becoming increasingly sophisticated at analyzing vast datasets (genomics, proteomics, patient data, scientific literature) to identify novel biological targets for new drugs. This speeds up the initial, often slow, phase of discovery.
# *   **De Novo Drug Design:** Instead of screening existing libraries of compounds, AI can now *design* novel drug molecules from scratch, optimizing for specific properties like binding affinity, efficacy, and reduced toxicity. This is a significant leap forward.
# *   **Predicting Drug Properties and Efficacy:** ML models are getting better at predicting how a drug candidate will behave in the body (pharmacokinetics) and its likely effectiveness, reducing the number of candidates that fail later in development.
# *   **Repurposing Existing Drugs:** AI is highly effective at finding new uses for already approved drugs, which can dramatically shorten the development timeline and reduce costs.
# *   **Optimizing Clinical Trial Design:** AI can help identify the most suitable patient populations for trials, predict response rates, and even simulate trial outcomes, making trials more efficient and increasing their chances of success.
#
#     *   **News Examples:** Companies like **Exscientia**, **BenevolentAI**, **Atomwise**, **Recursion Pharmaceuticals**, and **Insilico Medicine** are frequently announcing new AI-driven drug discovery partnerships with major pharmaceutical companies, significant funding rounds, and promising preclinical data. They are also increasingly moving their AI-discovered or designed drugs into clinical trials.
#
# **2. Advanced Modalities and Technologies:**
#
# *   **CRISPR and Gene Editing:** While not strictly "drug discovery" in the traditional sense, the ability to precisely edit genes is opening up entirely new therapeutic avenues. AI is crucial for identifying target genes and designing effective gene therapies.
# *   **RNA Therapeutics (mRNA, siRNA):** Building on the success of mRNA vaccines, researchers are exploring these modalities for a wider range of diseases. AI is helping to design more stable and effective RNA sequences.
# *   **Peptide Therapeutics:** Peptides are smaller than proteins but can still have potent therapeutic effects. AI is being used to design novel peptide drugs with improved stability and targeting.
# *   **Oligonucleotide Therapeutics:** These are short strands of DNA or RNA used to modulate gene expression. AI aids in designing these molecules to be specific and effective.
# *   **Targeted Protein Degradation (PROTACs and molecular glues):** These innovative approaches use the body's own systems to break down disease-causing proteins. AI is instrumental in designing these complex molecules.
#
# **3. New Scientific Insights and Data Sources:**
#
# *   **Single-Cell Genomics:** Analyzing the genetic makeup of individual cells provides unprecedented detail about disease mechanisms, enabling more precise drug target identification.
# *   **Spatial Biology:** Understanding the 3D organization of cells and tissues provides context that was previously unavailable, leading to new therapeutic hypotheses.
# *   **Microbiome Research:** The gut microbiome is increasingly recognized as a player in various diseases. AI is helping to decipher these complex interactions and identify potential drug targets within the microbiome.
#
# **4. Focus on "Undruggable" Targets:**
#
# *   A significant portion of disease-causing proteins are considered "undruggable" by conventional small molecules. New modalities and AI-driven design are making inroads into tackling these challenging targets.
#
# **5. Faster Path to Clinic:**
#
# *   The ultimate goal of these advancements is to significantly shorten the notoriously long and expensive drug development process. We are seeing more companies reporting that their AI-discovered or designed drugs are entering clinical trials at an accelerated pace.
#
# **In summary, the key takeaway is that AI is not just an incremental improvement in drug discovery; it's a fundamental shift.** It's enabling scientists to ask new questions, explore previously inaccessible biological space, and design medicines with unprecedented precision. Keep an eye on the companies and research institutions at the forefront of these AI-driven innovations for the most significant updates.
#
#  ### Session: compaction_demo
#
# User > Tell me more about the second development you found.
# gemini-2.5-flash-lite >  You're referring to the second development I mentioned in my previous response, which was:
#
# **2. Advanced Modalities and Technologies**
#
# This area is incredibly exciting because it's about developing entirely *new kinds of medicines* beyond the traditional small molecules and large protein-based biologics we've relied on for decades. AI plays a crucial role in enabling the discovery and design of these novel therapeutic approaches.
#
# Let's break down each of these advanced modalities:
#
# *   **CRISPR and Gene Editing:**
#     *   **What it is:** CRISPR-Cas9 (and its many variations) is a revolutionary technology that allows scientists to make precise edits to DNA. Think of it like a "molecular scissors" that can cut DNA at a specific location, enabling the removal, insertion, or modification of genes.
#     *   **Why it's advanced:** It offers the potential to correct the root cause of genetic diseases by fixing faulty genes.
#     *   **AI's Role:**
#         *   **Target Identification:** AI analyzes genomic data to identify specific genes responsible for diseases and the optimal sites for gene editing.
#         *   **Guide RNA Design:** CRISPR relies on "guide RNA" to direct the Cas enzyme to the correct DNA sequence. AI algorithms help design highly specific and efficient guide RNAs, minimizing off-target edits.
#         *   **Delivery System Optimization:** Getting the CRISPR machinery into the right cells in the body is a major challenge. AI can help design and optimize delivery vectors (like viruses or nanoparticles).
#     *   **News:** We're seeing increasing clinical trials for conditions like sickle cell disease, beta-thalassemia, and certain forms of blindness using CRISPR-based therapies. Companies like **CRISPR Therapeutics**, **Intellia Therapeutics**, and **Editas Medicine** are pioneers.
#
# *   **RNA Therapeutics (mRNA, siRNA):**
#     *   **What it is:**
#         *   **mRNA (messenger RNA):** This technology carries instructions for cells to produce specific proteins. The COVID-19 vaccines famously used mRNA. In drug discovery, mRNA can be engineered to instruct cells to produce therapeutic proteins or antigens for vaccines.
#         *   **siRNA (small interfering RNA):** These molecules are designed to "silence" specific genes by degrading their messenger RNA, thereby preventing the production of a problematic protein.
#     *   **Why it's advanced:** RNA-based therapies offer a way to modulate protein production without altering the permanent DNA sequence. They can be highly targeted and potentially reversible.
#     *   **AI's Role:**
#         *   **Sequence Optimization:** AI helps design mRNA or siRNA sequences that are stable, potent, and have minimal off-target effects.
#         *   **Delivery System Design:** Similar to CRISPR, AI assists in developing effective delivery mechanisms to get these fragile RNA molecules into cells.
#         *   **Predicting Efficacy and Toxicity:** ML models can predict how well an RNA therapeutic will work and identify potential safety concerns.
#     *   **News:** Beyond vaccines, mRNA is being explored for cancer immunotherapies, protein replacement therapies, and even infectious disease prevention. siRNA is showing promise in treating genetic liver diseases, cardiovascular conditions, and neurological disorders. Companies like **Moderna**, **BioNTech**, and **Alnylam Pharmaceuticals** are major players.
#
# *   **Peptide Therapeutics:**
#     *   **What it is:** Peptides are short chains of amino acids, smaller than proteins but larger than small molecules. They can act as hormones, neurotransmitters, or have direct therapeutic effects.
#     *   **Why it's advanced:** Peptides can often bind to targets that small molecules can't, and they can be designed to be highly specific.
#     *   **AI's Role:**
#         *   **Peptide Design:** AI can generate novel peptide sequences with desired binding properties, stability, and reduced immunogenicity.
#         *   **Predicting Bioactivity and Metabolism:** ML models can predict how a peptide will interact with biological systems and how it will be broken down in the body.
#     *   **News:** Peptide drugs are being developed for metabolic diseases (like diabetes and obesity, e.g., semaglutide), cancer, and chronic pain.
#
# *   **Oligonucleotide Therapeutics:**
#     *   **What it is:** These are short, synthetic strands of DNA or RNA that can bind to specific genetic sequences (DNA or RNA) to influence gene expression. This includes antisense oligonucleotides (ASOs) and other similar technologies.
#     *   **Why it's advanced:** They offer a precise way to modulate gene activity, either by blocking the production of harmful proteins or by correcting errors.
#     *   **AI's Role:**
#         *   **Sequence Design:** AI is crucial for designing oligonucleotides that are highly specific to their target and resistant to degradation.
#         *   **Predicting Off-Target Binding:** Ensuring these molecules only affect the intended genetic target is critical, and AI helps in this prediction.
#     *   **News:** This class of drugs is gaining traction for rare genetic diseases and certain types of cancer.
#
# *   **Targeted Protein Degradation (e.g., PROTACs):**
#     *   **What it is:** Instead of just inhibiting a disease-causing protein, PROTACs (Proteolysis-Targeting Chimeras) and similar technologies recruit the cell's natural "garbage disposal" system (the ubiquitin-proteasome system) to actively break down and eliminate the target protein.
#     *   **Why it's advanced:** This approach can tackle proteins that are difficult or impossible to inhibit with traditional drugs and can achieve deeper and more sustained target clearance.
#     *   **AI's Role:**
#         *   **Designing Bifunctional Molecules:** PROTACs are complex molecules with two distinct binding regions. AI is essential for designing these dual-acting molecules, connecting the target protein binder with the E3 ligase binder.
#         *   **Predicting Degradation Efficiency:** ML models help predict how effectively a PROTAC will degrade its target protein.
#     *   **News:** This is a rapidly emerging area with significant investment, showing promise for various cancers and other diseases.
#
# These "advanced modalities" represent a significant departure from traditional drug discovery, offering new ways to combat diseases at their fundamental molecular and genetic levels. AI is the key enabler, allowing researchers to design and optimize these complex new therapeutic agents more efficiently than ever before.
#
#  ### Session: compaction_demo
#
# User > Who are the main companies involved in that?
# gemini-2.5-flash-lite >  You're asking about the main companies involved in the development and application of these **Advanced Modalities and Technologies** in drug discovery. This is a very active and competitive space, with both established pharmaceutical giants and innovative biotech startups playing crucial roles.
#
# Here's a breakdown by modality, highlighting some key players:
#
# **1. CRISPR and Gene Editing:**
#
# *   **Pioneering Biotech Companies:**
#     *   **CRISPR Therapeutics:** A leader in developing CRISPR-based therapies for serious diseases like sickle cell disease and beta-thalassemia.
#     *   **Intellia Therapeutics:** Focused on developing CRISPR-based therapies, including treatments for transthyretin amyloidosis and hereditary angioedema.
#     *   **Editas Medicine:** Also developing CRISPR-based therapies, with a focus on inherited blindness and sickle cell disease.
#     *   **Beam Therapeutics:** Focuses on a related but distinct technology called "base editing," which allows for more precise single-letter DNA changes without cutting both strands of DNA.
# *   **Major Pharmaceutical Companies (often through partnerships and acquisitions):**
#     *   **Vertex Pharmaceuticals:** Has a significant collaboration with CRISPR Therapeutics.
#     *   **Gilead Sciences:** Invests in and partners with gene editing companies.
#     *   **Roche, Novartis, Pfizer, and others:** Are actively monitoring the field, investing, and forming strategic alliances.
#
# **2. RNA Therapeutics (mRNA, siRNA):**
#
# *   **mRNA Leaders:**
#     *   **Moderna:** A household name due to its COVID-19 vaccine, now rapidly expanding its mRNA platform for other infectious diseases, cancer vaccines, and rare diseases.
#     *   **BioNTech:** Co-developer of the Pfizer-BioNTech COVID-19 vaccine, also has a robust mRNA pipeline for cancer immunotherapies and other diseases.
#     *   **CureVac:** Another company developing mRNA-based vaccines and therapeutics.
# *   **siRNA Leaders:**
#     *   **Alnylam Pharmaceuticals:** A pioneer in the siRNA space, with several approved drugs for rare genetic diseases (e.g., ONPATTRO, GIVLAARI).
#     *   **Ionis Pharmaceuticals:** Develops antisense oligonucleotide (ASO) therapies, which are related to RNA therapeutics.
#     *   **Arrowhead Pharmaceuticals:** Focuses on RNA interference (RNAi) therapeutics using various delivery technologies.
# *   **Major Pharmaceutical Companies:** Many large pharma companies are investing heavily in mRNA and siRNA, often through partnerships with the biotech leaders above, or by developing their own internal RNA capabilities.
#
# **3. Peptide Therapeutics:**
#
# *   **Companies with Approved Peptide Drugs:**
#     *   **Novo Nordisk:** A giant in the field, known for its GLP-1 receptor agonists for diabetes and obesity (e.g., Ozempic, Wegovy).
#     *   **Eli Lilly and Company:** Also a major player in GLP-1 agonists (e.g., Trulicity, Mounjaro) and other peptide-based therapies.
#     *   **Takeda Pharmaceutical Company:** Has approved peptide drugs for rare diseases.
# *   **Companies Developing Novel Peptide Platforms:**
#     *   There are numerous smaller biotech companies focused on designing and developing peptide drugs for various indications, often leveraging AI for design.
#
# **4. Oligonucleotide Therapeutics (ASOs, etc.):**
#
# *   **Leading Companies:**
#     *   **Ionis Pharmaceuticals:** A major developer of antisense oligonucleotide (ASO) therapies. They have several approved drugs for genetic neurological and neuromuscular diseases.
#     *   **Biogen:** Has partnered with Ionis and developed its own oligonucleotide therapies, particularly for neurological disorders.
#     *   **Roche:** Has developed and markets ASOs for specific genetic conditions.
#     *   **Sarepta Therapeutics:** Known for its ASO therapies for Duchenne muscular dystrophy.
#
# **5. Targeted Protein Degradation (PROTACs and Molecular Glues):**
#
# *   **Pioneering Biotech Companies:**
#     *   **Arvinas:** A leader in PROTAC technology, with therapies in clinical development for breast cancer and prostate cancer.
#     *   **Kymera Therapeutics:** Focuses on discovering and developing small molecule drugs that harness protein degradation pathways.
#     *   **Nurix Therapeutics:** Develops drugs that modulate the E3 ubiquitin ligase complex to induce protein degradation.
# *   **Major Pharmaceutical Companies:**
#     *   **Pfizer:** Has significant collaborations and internal programs in protein degradation.
#     *   **Merck:** Investing in and partnering with companies in this space.
#     *   **Bristol Myers Squibb, Novartis, and others:** Are also actively pursuing this modality through internal research and partnerships.
#
# **Key Trends and the Role of AI:**
#
# It's important to note that many companies, especially the large pharmaceutical ones, are not solely focused on one modality. They are building broad platforms and often use **AI and machine learning** across *all* these areas for target identification, molecule design, predicting efficacy, and optimizing delivery.
#
# Furthermore, there's a lot of **collaboration and acquisition activity**. Large pharmaceutical companies often partner with smaller, more specialized biotech firms that have expertise in a particular advanced modality, or they acquire them outright to gain access to their technology and pipeline.
#
# This is a rapidly evolving landscape, so new players emerge, and established ones forge new alliances regularly.

# %% [markdown]
# ### 4.3 Verifying Compaction in the Session History
#
# The conversation above looks normal, but the history has been changed behind the scenes. How can we prove it?
#
# We can inspect the `events` list from our session. The compaction process **doesn't delete old events; it replaces them with a single, new `Event` that contains the summary.** Let's find it.

# %%
# Get the final session state
final_session = await session_service.get_session(
    app_name=research_runner_compacting.app_name,
    user_id=USER_ID,
    session_id="compaction_demo",
)

print("--- Searching for Compaction Summary Event ---")
found_summary = False
for event in final_session.events:
    # Compaction events have a 'compaction' attribute
    if event.actions and event.actions.compaction:
        print("\n✅ SUCCESS! Found the Compaction Event:")
        print(f"  Author: {event.author}")
        print(f"\n Compacted information: {event}")
        found_summary = True
        break

if not found_summary:
    print(
        "\n❌ No compaction event found. Try increasing the number of turns in the demo."
    )
# Out:
# --- Searching for Compaction Summary Event ---
#
# ✅ SUCCESS! Found the Compaction Event:
#   Author: user
#
#  Compacted information: model_version=None content=None grounding_metadata=None partial=None turn_complete=None finish_reason=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None invocation_id='b5f3e0e5-f1ab-4b13-a482-a6fce302df48' author='user' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction={'start_timestamp': 1763225828.382669, 'end_timestamp': 1763225838.346331, 'compacted_content': {'parts': [{'function_call': None, 'code_execution_result': None, 'executable_code': None, 'file_data': None, 'function_response': None, 'inline_data': None, 'text': 'The user inquired about the latest news in AI in healthcare. The AI agent provided a comprehensive overview, categorizing advancements into key areas such as drug discovery, medical imaging analysis, personalized medicine, diagnostics, robotics, and operational efficiency. A significant emerging trend highlighted was the application of Generative AI (LLMs) for tasks like clinical documentation and patient education, while also noting challenges related to accuracy and privacy. The agent also mentioned the growing importance of Explainable AI (XAI) and AI\'s role in mental health and the evolving regulatory landscape.\n\nThe user then asked for more details on drug discovery developments. The AI agent elaborated on how AI is revolutionizing drug discovery by accelerating target identification, enabling de novo drug design, predicting drug properties, repurposing existing drugs, and optimizing clinical trials. Specific companies like Exscientia, BenevolentAI, and Atomwise were mentioned as leaders in this field.\n\nFinally, the user requested more information on the second development previously mentioned: "Advanced Modalities and Technologies." The AI agent explained several cutting-edge therapeutic approaches:\n*   **CRISPR and Gene Editing:** AI\'s role in target identification, guide RNA design, and delivery system optimization was discussed, with clinical trials for genetic diseases highlighted.\n*   **RNA Therapeutics (mRNA, siRNA):** AI\'s contribution to sequence optimization, delivery system design, and efficacy prediction was detailed, noting applications beyond vaccines.\n*   **Peptide Therapeutics:** AI\'s use in designing novel peptide sequences with desired properties was explained.\n*   **Oligonucleotide Therapeutics:** AI\'s importance in designing specific and stable oligonucleotide sequences was covered.\n*   **Targeted Protein Degradation (PROTACs):** AI\'s role in designing these complex molecules and predicting their degradation efficiency was described, highlighting their potential for "undruggable" targets.\n\n**Key Decisions Made:**\n*   The AI agent decided to provide a broad overview of AI in healthcare initially, followed by deeper dives into specific areas requested by the user.\n\n**Unresolved Questions/Tasks:**\n*   There are no explicit unresolved questions or tasks from the user in this conversation history. The conversation is informative and the user is seeking knowledge.', 'thought': None, 'thought_signature': None, 'video_metadata': None}], 'role': 'model'}}, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=set() branch=None id='53bf4156-a4e6-4e85-8896-191d5301eb0a' timestamp=1763225844.915516

# %% [markdown]
# ### 4.4 What you've accomplished: Automatic Context Management
#
# You just found the proof! The presence of that special summary `Event` in your session's history is the tangible result of the compaction process.
#
# **Let's recap what you just witnessed:**
#
# 1.  **Silent Operation**: You ran a standard conversation, and from the outside, nothing seemed different.
# 2.  **Background Compaction**: Because you configured the `App` with `EventsCompactionConfig`, the ADK `Runner` automatically monitored the conversation length. Once the threshold was met, it triggered the summarization process in the background.
# 3.  **Verified Result**: By inspecting the session's events, you found the summary that the LLM generated. This summary now replaces the older, more verbose turns in the agent's active context.
#
# **For all future turns in this conversation, the agent will be given this concise summary instead of the full history.** This saves costs, improves performance, and helps the agent stay focused on what's most important.

# %% [markdown]
# ### 4.5 More Context Engineering options in ADK
#
# #### 👉 Custom Compaction
# In this example, we used ADK's default summarizer. For more advanced use cases, you can provide your own by defining a custom `SlidingWindowCompactor` and passing it to the config. This allows you to control the summarization prompt or even use a different, specialized LLM for the task. You can read more about it in the [official documentation](https://google.github.io/adk-docs/context/compaction/).
#
# #### 👉 Context Caching
# ADK also provides **Context Caching** to help reduce the token size of the static instructions that are fed to the LLM by caching the request data. Read more about it [here](https://google.github.io/adk-docs/context/caching/).

# %% [markdown]
# ### The Problem
#
# While we can do Context Compaction and use a database to resume a session, we face new challenges now. In some cases, **we have key information or preferences that we want to share across other sessions.**
#
# In these scenarios, instead of sharing the entire session history, transferring information from a few key variables can improve the session experience. Let's see how to do it!

# %% [markdown]
# ---
# ## 🤝 Section 5: Working with Session State
#
# ### 5.1 Creating custom tools for Session state management
#
# Let's explore how to manually manage session state through custom tools. In this example, we'll identify a **transferable characteristic**, like a user's name and their country, and create tools to capture and save it.
#
# **Why This Example?**
#
# The username is a perfect example of information that:
#
# - Is introduced once but referenced multiple times
# - Should persist throughout a conversation
# - Represents a user-specific characteristic that enhances personalization
#
# Here, for demo purposes, we'll create two tools that can store and retrieve user name and country from the Session State. **Note that all tools have access to the `ToolContext` object.** You don't have to create separate tools for each piece of information you want to share.

# %%
# Define scope levels for state keys (following best practices)
USER_NAME_SCOPE_LEVELS = ("temp", "user", "app")


# This demonstrates how tools can write to session state using tool_context.
# The 'user:' prefix indicates this is user-specific data.
def save_userinfo(
    tool_context: ToolContext, user_name: str, country: str
) -> Dict[str, Any]:
    """
    Tool to record and save user name and country in session state.

    Args:
        user_name: The username to store in session state
        country: The name of the user's country
    """
    # Write to session state using the 'user:' prefix for user data
    tool_context.state["user:name"] = user_name
    tool_context.state["user:country"] = country

    return {"status": "success"}


# This demonstrates how tools can read from session state.
def retrieve_userinfo(tool_context: ToolContext) -> Dict[str, Any]:
    """
    Tool to retrieve user name and country from session state.
    """
    # Read from session state
    user_name = tool_context.state.get("user:name", "Username not found")
    country = tool_context.state.get("user:country", "Country not found")

    return {"status": "success", "user_name": user_name, "country": country}


print("✅ Tools created.")
# Out:
# ✅ Tools created.

# %% [markdown]
# **Key Concepts:**
# - Tools can access `tool_context.state` to read/write session state
# - Use descriptive key prefixes (`user:`, `app:`, `temp:`) for organization
# - State persists across conversation turns within the same session

# %% [markdown]
# ### 5.2 Creating an Agent with Session State Tools
#
# Now let's create a new agent that has access to our session state management tools:

# %%
# Configuration
APP_NAME = "default"
USER_ID = "default"
MODEL_NAME = "gemini-2.5-flash-lite"

# Create an agent with session state tools
root_agent = LlmAgent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="text_chat_bot",
    description="""A text chatbot.
    Tools for managing user context:
    * To record username and country when provided use `save_userinfo` tool. 
    * To fetch username and country when required use `retrieve_userinfo` tool.
    """,
    tools=[save_userinfo, retrieve_userinfo],  # Provide the tools to the agent
)

# Set up session service and runner
session_service = InMemorySessionService()
runner = Runner(agent=root_agent, session_service=session_service, app_name="default")

print("✅ Agent with session state tools initialized!")
# Out:
# ✅ Agent with session state tools initialized!

# %% [markdown]
# ### 5.3 Testing Session State in Action
#
# Let's test how the agent uses session state to remember information across conversation turns:

# %%
# Test conversation demonstrating session state
await run_session(
    runner,
    [
        "Hi there, how are you doing today? What is my name?",  # Agent shouldn't know the name yet
        "My name is Sam. I'm from Poland.",  # Provide name - agent should save it
        "What is my name? Which country am I from?",  # Agent should recall from session state
    ],
    "state-demo-session",
)
# Out:
#  ### Session: state-demo-session
#
# User > Hi there, how are you doing today? What is my name?
# gemini-2.5-flash-lite >  Hello! I'm doing great. I'd love to tell you your name, but I don't have access to that information. My apologies!
#
#
# User > My name is Sam. I'm from Poland.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# gemini-2.5-flash-lite >  It is a pleasure to meet you, Sam! I will remember that you are from Poland.
#
#
# User > What is my name? Which country am I from?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# gemini-2.5-flash-lite >  Your name is Sam and you are from Poland.

# %% [markdown]
# ### 5.4 Inspecting Session State
#
# Let's directly inspect the session state to see what's stored:

# %%
# Retrieve the session and inspect its state
session = await session_service.get_session(
    app_name=APP_NAME, user_id=USER_ID, session_id="state-demo-session"
)

print("Session State Contents:")
print(session.state)
print("\n🔍 Notice the 'user:name' and 'user:country' keys storing our data!")
# Out:
# Session State Contents:
# {'user:name': 'Sam', 'user:country': 'Poland'}
#
# 🔍 Notice the 'user:name' and 'user:country' keys storing our data!

# %% [markdown]
# ### 5.5 Session State Isolation
#
# As we've already seen, an important characteristic of session state is that it's isolated per session. Let's demonstrate this by starting a new session:

# %%
# Start a completely new session - the agent won't know our name
await run_session(
    runner,
    ["Hi there, how are you doing today? What is my name?"],
    "new-isolated-session",
)

# Expected: The agent won't know the name because this is a different session
# Out:
#  ### Session: new-isolated-session
#
# User > Hi there, how are you doing today? What is my name?
# gemini-2.5-flash-lite >  I'm doing great, thank you for asking! I'd love to tell you your name, but I don't have access to that information.

# %% [markdown]
# ### 5.6 Cross-Session State Sharing
#
# While sessions are isolated by default, you might notice something interesting. Let's check the state of our new session (`new-isolated-session`):

# %%
# Check the state of the new session
session = await session_service.get_session(
    app_name=APP_NAME, user_id=USER_ID, session_id="new-isolated-session"
)

print("New Session State:")
print(session.state)

# Note: Depending on implementation, you might see shared state here.
# This is where the distinction between session-specific and user-specific state becomes important.
# Out:
# New Session State:
# {'user:name': 'Sam', 'user:country': 'Poland'}

# %% [markdown]
# ---
#
# ## 🧹 Cleanup

# %%
# Clean up any existing database to start fresh (if Notebook is restarted)
import os

if os.path.exists("my_agent_data.db"):
    os.remove("my_agent_data.db")
print("✅ Cleaned up old database files")
# Out:
# ✅ Cleaned up old database files

# %% [markdown]
# ---
# ## 📊 Summary
#
# 🎉 Congratulations! You've learned the fundamentals of building stateful AI agents:
#
# - ✅ **Context Engineering** - You understand how to assemble context for LLMs using Context Compaction
# - ✅ **Sessions & Events** - You can maintain conversation history across multiple turns
# - ✅ **Persistent Storage** - You know how to make conversations survive restarts
# - ✅ **Session State** - You can track structured data during conversations
# - ✅ **Manual State Management** - You've experienced both the power and limitations of manual approaches
# - ✅ **Production Considerations** - You're ready to handle real-world challenges
